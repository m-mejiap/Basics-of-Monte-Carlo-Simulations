# %%
import numpy as np
import matplotlib.pylab as plt

# %%
data = np.genfromtxt("data.dat",delimiter=",")

# %%
plt.figure()
plt.scatter(data[:,1],data[:,0],color="grey",marker=".")
plt.xlabel("Number needles used in the simulations. (n)")
plt.ylabel("Average error.")
plt.title("Graph 1: Average error vs. Number needles.")
#plt.savefig("plot1.png")
# Out:
# Text(0.5, 1.0, 'Graph 1: Average error vs. Number needles.')
